# %%
import pandas as pd

# %%
df = pd.read_excel('/home/laertio/projects/dev/tv_scan/components/spotreg_update/data_in/input_sample.xlsx')

# %%
df.head()
# Out:
#    MediaDesc   SolDate  SolDateArch  SolDatePub  SpotCode  \
# 0  Televisão  20220101     20220224    20220101    412561
# 1  Televisão  20220101     20220224    20220101    412475
# 2  Televisão  20220101     20220224    20220101  39894801
# 3  Televisão  20220101     20220224    20220101    411731
# 4  Televisão  20220101     20220224    20220101    414824
#
#                                             SpotDesc  SitCampId  \
# 0       SABADO E DOMINGO 11/15H TEATRO POLITEAMA.RTP          2
# 1           SABADO E DOMINGO 11/15H TEATRO POLITEAMA          2
# 2  APRESENTAMOS ORAL B IO A REVOLUCIONARIA TECNOL...          2
# 3                                  QUI A SAB/DOM.RTP          2
# 4  PAT.MASTERCHEF-A VARIEDADE QUALIDADE E FRESCUR...          2
#
#      SitCampDesc   VehicleDesc                     BrandDesc SubBrandDesc  \
# 0  Nova Campanha          RTP1    A PEQUENA SEREIA (MUSICAL)          NaN
# 1  Nova Campanha         Panda    A PEQUENA SEREIA (MUSICAL)          NaN
# ...

# %%
df.SpotCode.value_counts()
# Out:
# 417299    10
# 359651    10
# 419737     9
# 417344     9
# 417461     9
#           ..
# 423093     1
# 423106     1
# 423107     1
# 423112     1
# 430690     1
# Name: SpotCode, Length: 12995, dtype: int64

# %%
df.loc[df.SpotCode.eq(417299)]
# Out:
#        MediaDesc   SolDate  SolDateArch  SolDatePub  SpotCode  \
# 129    Televisão  20220103     20220114    20220103    417299
# 1242   Televisão  20220207     20220303    20220207    417299
# 3724   Televisão  20220411     20220427    20220411    417299
# 5732   Televisão  20220530     20220609    20220530    417299
# 6881   Televisão  20220627     20220713    20220627    417299
# 7971   Televisão  20220725     20220902    20220725    417299
# 8792   Televisão  20220822     20220915    20220822    417299
# 9964   Televisão  20220919     20221020    20220919    417299
# 11521  Televisão  20221024     20221103    20221024    417299
# 12926  Televisão  20221121     20221202    20221121    417299
#
#                         SpotDesc  SitCampId    SitCampDesc VehicleDesc  \
# 129    RED BULL DA-TE ASAS.MELGA          4     Novo Filme         TVI
# 1242   RED BULL DA-TE ASAS.MELGA          2  Nova Campanha         FOX
# ...

# %%
df.iloc[129,17]
# Out:
# 'http://e-sol.mediamonitor.pt/SOLFILES/TELEVISAO/20220103/417299.wmv'

# %%
df = df.drop_duplicates(subset='SpotCode', keep='first')

# %%
keep_cols = ['SpotCode',
             'SpotDesc',
             'VehicleDesc',
             'BrandDesc',
             'SubBrandDesc',
             'SectorDesc',
             'CategoryDesc',
             'ClassDesc',
             'SubClassDesc',
             'AdvertiserDesc',
             'MediaFile',
             'MediaFileOldUrl']

df = df.loc[:,keep_cols]

# %%
list(df['SpotCode'])
# Out:
# [412561,
#  412475,
#  39894801,
#  411731,
#  414824,
#  415702,
#  402151,
#  413090,
#  414576,
#  382116,
#  397009,
#  397204,
#  411326,
#  389966,
#  28947201,
#  399212,
#  395281,
#  410473,
#  417250,
#  402883,
#  411348,
#  411733,
#  412876,
#  413594,
#  412867,
#  415321,
#  397749,
#  417209,
#  417210,
#  417217,
#  417224,
#  417213,
#  417222,
#  417215,
#  417229,
#  417231,
#  417230,
#  417211,
#  417212,
#  417223,
#  417214,
#  417216,
#  417218,
#  417225,
#  417232,
#  417219,
#  417220,
#  417240,
#  417265,
#  417268,
#  417280,
#  417281,
#  417226,
#  417245,
#  417227,
#  417285,
#  417233,
#  417234,
#  417235,
#  417236,
#  417238,
#  417247,
#  417239,
#  417242,
#  417248,
#  417249,
#  417246,
#  417237,
#  417221,
#  417243,
#  417241,
#  417251,
#  417252,
#  417253,
#  417254,
#  417255,
#  417256,
#  417257,
#  417258,
#  417259,
#  417260,
#  417261,
#  417267,
#  417274,
#  417263,
#  417266,
#  417262,
#  417273,
#  417278,
#  417277,
# ...
